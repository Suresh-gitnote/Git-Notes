# %%
import pandas as pd
data=pd.read_csv("Students Mark List.csv")
data
# Out:
#     Student Name  Tamil  English  Maths  Science  Social Science  Total Mark  \
# 0          Thiru     51     47.0   75.0     67.0            87.0       327.0
# 1          Madan     58     83.0   86.0     89.0            96.0       412.0
# 2          Aruna     58     60.0    NaN     97.0            95.0       371.0
# 3         Sanjay     52     66.0   55.0     41.0            77.0       291.0
# 4          Umesh     56     73.0   53.0     79.0             NaN       357.0
# ..           ...    ...      ...    ...      ...             ...         ...
# 195     Sudhakar     43     92.0   91.0     98.0            89.0       413.0
# 196      Sowmiya     45     67.0   45.0     40.0            43.0       240.0
# 197    Hemapriya     58     75.0   23.0     12.0            16.0       184.0
# 198       Kothai     95     57.0   89.0     78.0            65.0       384.0
# 199        Gowri     33     89.0   78.0     69.0            82.0       351.0
#
#     Grade Result
# 0       C   Pass
# ...

# %%
data.head()
# Out:
#   Student Name  Tamil  English  Maths  Science  Social Science  Total Mark  \
# 0        Thiru     51     47.0   75.0     67.0            87.0       327.0
# 1        Madan     58     83.0   86.0     89.0            96.0       412.0
# 2        Aruna     58     60.0    NaN     97.0            95.0       371.0
# 3       Sanjay     52     66.0   55.0     41.0            77.0       291.0
# 4        Umesh     56     73.0   53.0     79.0             NaN       357.0
#
#   Grade Result
# 0     C   Pass
# 1     B   Pass
# 2     C   Pass
# 3     D   Pass
# 4     C   Pass

# %%
data.head(2)
# Out:
#   Student Name  Tamil  English  Maths  Science  Social Science  Total Mark  \
# 0        Thiru     51     47.0   75.0     67.0            87.0       327.0
# 1        Madan     58     83.0   86.0     89.0            96.0       412.0
#
#   Grade Result
# 0     C   Pass
# 1     B   Pass

# %%
data.head(10)
# Out:
#   Student Name  Tamil  English  Maths  Science  Social Science  Total Mark  \
# 0        Thiru     51     47.0   75.0     67.0            87.0       327.0
# 1        Madan     58     83.0   86.0     89.0            96.0       412.0
# 2        Aruna     58     60.0    NaN     97.0            95.0       371.0
# 3       Sanjay     52     66.0   55.0     41.0            77.0       291.0
# 4        Umesh     56     73.0   53.0     79.0             NaN       357.0
# 5  Chiranjeevi     52     49.0   80.0     69.0            93.0       343.0
# 6  Varalakshmi     87     98.0   79.0     92.0            86.0       442.0
# 7      Revathi     48     47.0   68.0     98.0            83.0       344.0
# 8     Gayathri     92     77.0    NaN     80.0            94.0       424.0
# 9        Vijay     82     91.0   74.0     75.0            73.0       395.0
#
#   Grade Result
# 0     C   Pass
# 1     B   Pass
# 2     C   Pass
# 3     D   Pass
# 4     C   Pass
# 5   NaN    NaN
# 6     B   Pass
# ...

# %%
data.tail()
# Out:
#     Student Name  Tamil  English  Maths  Science  Social Science  Total Mark  \
# 195     Sudhakar     43     92.0   91.0     98.0            89.0       413.0
# 196      Sowmiya     45     67.0   45.0     40.0            43.0       240.0
# 197    Hemapriya     58     75.0   23.0     12.0            16.0       184.0
# 198       Kothai     95     57.0   89.0     78.0            65.0       384.0
# 199        Gowri     33     89.0   78.0     69.0            82.0       351.0
#
#     Grade Result
# 195     B   Pass
# 196     D   Pass
# 197     E   Fail
# 198     C   Pass
# 199     C   Fail

# %%
data.describe()
# Out:
#             Tamil     English       Maths     Science  Social Science  \
# count  200.000000  198.000000  196.000000  198.000000      198.000000
# mean    66.225000   65.984848   66.658163   66.813131       65.520202
# std     22.430784   21.437544   22.353580   20.734983       22.914033
# min      0.000000    7.000000    5.000000    8.000000        1.000000
# 25%     51.000000   50.250000   53.000000   51.000000       49.250000
# 50%     66.000000   67.000000   69.000000   69.000000       68.000000
# 75%     86.250000   83.000000   84.000000   83.000000       85.000000
# max    100.000000  100.000000  100.000000  100.000000      100.000000
#
#        Total Mark
# count  199.000000
# mean   331.371859
# std     61.500451
# min    143.000000
# 25%    296.500000
# 50%    338.000000
# 75%    371.000000
# max    500.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student Name    200 non-null    object
#  1   Tamil           200 non-null    int64
#  2   English         198 non-null    float64
#  3   Maths           196 non-null    float64
#  4   Science         198 non-null    float64
#  5   Social Science  198 non-null    float64
#  6   Total Mark      199 non-null    float64
#  7   Grade           196 non-null    object
#  8   Result          199 non-null    object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 14.2+ KB

# %%
empty_cells = data.isnull()
print(empty_cells)
# Out:
#      Student Name  Tamil  English  Maths  Science  Social Science  Total Mark  \
# 0           False  False    False  False    False           False       False
# 1           False  False    False  False    False           False       False
# 2           False  False    False   True    False           False       False
# 3           False  False    False  False    False           False       False
# 4           False  False    False  False    False            True       False
# ..            ...    ...      ...    ...      ...             ...         ...
# 195         False  False    False  False    False           False       False
# 196         False  False    False  False    False           False       False
# 197         False  False    False  False    False           False       False
# 198         False  False    False  False    False           False       False
# 199         False  False    False  False    False           False       False
#
#      Grade  Result
# ...

# %%
empty_cells = data.isnull().sum()
print(empty_cells)
# Out:
# Student Name      0
# Tamil             0
# English           2
# Maths             4
# Science           2
# Social Science    2
# Total Mark        1
# Grade             4
# Result            1
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

data["Grade"] = label_encoder.fit_transform(data["Grade"])
data
# Out:
#     Student Name  Tamil  English  Maths  Science  Social Science  Total Mark  \
# 0          Thiru     51     47.0   75.0     67.0            87.0       327.0
# 1          Madan     58     83.0   86.0     89.0            96.0       412.0
# 2          Aruna     58     60.0    NaN     97.0            95.0       371.0
# 3         Sanjay     52     66.0   55.0     41.0            77.0       291.0
# 4          Umesh     56     73.0   53.0     79.0             NaN       357.0
# ..           ...    ...      ...    ...      ...             ...         ...
# 195     Sudhakar     43     92.0   91.0     98.0            89.0       413.0
# 196      Sowmiya     45     67.0   45.0     40.0            43.0       240.0
# 197    Hemapriya     58     75.0   23.0     12.0            16.0       184.0
# 198       Kothai     95     57.0   89.0     78.0            65.0       384.0
# 199        Gowri     33     89.0   78.0     69.0            82.0       351.0
#
#      Grade Result
# 0        2   Pass
# ...

# %%
T=data["Tamil"].mean()
T
# Out:
# np.float64(66.225)

# %%
E=data["English"].mean()
E
# Out:
# np.float64(65.98484848484848)

# %%
M=data["Maths"].mean()
M
# Out:
# np.float64(66.65816326530613)

# %%
S=data["Science"].mean()
S
# Out:
# np.float64(66.81313131313131)

# %%
SS=data["Social Science"].mean()
SS
# Out:
# np.float64(65.52020202020202)

# %%
TM=data["Total Mark"].mean()
TM
# Out:
# np.float64(331.3718592964824)

# %%
data["Tamil"].fillna(T,inplace=True)
data["English"].fillna(E,inplace=True)
data["Maths"].fillna(M,inplace=True)
data["Science"].fillna(S,inplace=True)
data["Social Science"].fillna(SS,inplace=True)
data["Total Mark"].fillna(TM,inplace=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14364\1964233839.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Tamil"].fillna(T,inplace=True)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14364\1964233839.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data
# Out:
#     Student Name  Tamil  English      Maths  Science  Social Science  \
# 0          Thiru     51     47.0  75.000000     67.0       87.000000
# 1          Madan     58     83.0  86.000000     89.0       96.000000
# 2          Aruna     58     60.0  66.658163     97.0       95.000000
# 3         Sanjay     52     66.0  55.000000     41.0       77.000000
# 4          Umesh     56     73.0  53.000000     79.0       65.520202
# ..           ...    ...      ...        ...      ...             ...
# 195     Sudhakar     43     92.0  91.000000     98.0       89.000000
# 196      Sowmiya     45     67.0  45.000000     40.0       43.000000
# 197    Hemapriya     58     75.0  23.000000     12.0       16.000000
# 198       Kothai     95     57.0  89.000000     78.0       65.000000
# 199        Gowri     33     89.0  78.000000     69.0       82.000000
#
#      Total Mark  Grade Result
# 0         327.0      2   Pass
# 1         412.0      1   Pass
# 2         371.0      2   Pass
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

data["Result"] = label_encoder.fit_transform(data["Result"])
data
# Out:
#     Student Name  Tamil  English      Maths  Science  Social Science  \
# 0          Thiru     51     47.0  75.000000     67.0       87.000000
# 1          Madan     58     83.0  86.000000     89.0       96.000000
# 2          Aruna     58     60.0  66.658163     97.0       95.000000
# 3         Sanjay     52     66.0  55.000000     41.0       77.000000
# 4          Umesh     56     73.0  53.000000     79.0       65.520202
# ..           ...    ...      ...        ...      ...             ...
# 195     Sudhakar     43     92.0  91.000000     98.0       89.000000
# 196      Sowmiya     45     67.0  45.000000     40.0       43.000000
# 197    Hemapriya     58     75.0  23.000000     12.0       16.000000
# 198       Kothai     95     57.0  89.000000     78.0       65.000000
# 199        Gowri     33     89.0  78.000000     69.0       82.000000
#
#      Total Mark  Grade  Result
# 0         327.0      2       1
# 1         412.0      1       1
# 2         371.0      2       1
# ...

# %%
missingvalue = data.isnull()
missingvalue
# Out:
#      Student Name  Tamil  English  Maths  Science  Social Science  Total Mark  \
# 0           False  False    False  False    False           False       False
# 1           False  False    False  False    False           False       False
# 2           False  False    False  False    False           False       False
# 3           False  False    False  False    False           False       False
# 4           False  False    False  False    False           False       False
# ..            ...    ...      ...    ...      ...             ...         ...
# 195         False  False    False  False    False           False       False
# 196         False  False    False  False    False           False       False
# 197         False  False    False  False    False           False       False
# 198         False  False    False  False    False           False       False
# 199         False  False    False  False    False           False       False
#
#      Grade  Result
# ...

# %%
missingvalue = data.isnull().sum()
missingvalue
# Out:
# Student Name      0
# Tamil             0
# English           0
# Maths             0
# Science           0
# Social Science    0
# Total Mark        0
# Grade             0
# Result            0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data1=data.drop(["Student Name"],axis=1)
correlation_matrix = data1.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
data
# Out:
#     Student Name  Tamil  English      Maths  Science  Social Science  \
# 0          Thiru     51     47.0  75.000000     67.0       87.000000
# 1          Madan     58     83.0  86.000000     89.0       96.000000
# 2          Aruna     58     60.0  66.658163     97.0       95.000000
# 3         Sanjay     52     66.0  55.000000     41.0       77.000000
# 4          Umesh     56     73.0  53.000000     79.0       65.520202
# ..           ...    ...      ...        ...      ...             ...
# 195     Sudhakar     43     92.0  91.000000     98.0       89.000000
# 196      Sowmiya     45     67.0  45.000000     40.0       43.000000
# 197    Hemapriya     58     75.0  23.000000     12.0       16.000000
# 198       Kothai     95     57.0  89.000000     78.0       65.000000
# 199        Gowri     33     89.0  78.000000     69.0       82.000000
#
#      Total Mark  Grade  Result
# 0         327.0      2       1
# 1         412.0      1       1
# 2         371.0      2       1
# ...

# %%
X=data.drop(['Student Name',"Total Mark","Grade","Result"],axis=1)
Y=data["Total Mark"]

# %%
X
# Out:
#      Tamil  English      Maths  Science  Social Science
# 0       51     47.0  75.000000     67.0       87.000000
# 1       58     83.0  86.000000     89.0       96.000000
# 2       58     60.0  66.658163     97.0       95.000000
# 3       52     66.0  55.000000     41.0       77.000000
# 4       56     73.0  53.000000     79.0       65.520202
# ..     ...      ...        ...      ...             ...
# 195     43     92.0  91.000000     98.0       89.000000
# 196     45     67.0  45.000000     40.0       43.000000
# 197     58     75.0  23.000000     12.0       16.000000
# 198     95     57.0  89.000000     78.0       65.000000
# 199     33     89.0  78.000000     69.0       82.000000
#
# [200 rows x 5 columns]

# %%
Y
# Out:
# 0      327.0
# 1      412.0
# 2      371.0
# 3      291.0
# 4      357.0
#        ...
# 195    413.0
# 196    240.0
# 197    184.0
# 198    384.0
# 199    351.0
# Name: Total Mark, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=30)

# %%
X_train.head()
# Out:
#      Tamil  English  Maths  Science  Social Science
# 125     96     61.0   86.0     74.0            48.0
# 60      69     61.0   61.0     78.0            70.0
# 90      89     75.0   93.0     78.0            46.0
# 152     46     75.0   99.0     69.0            91.0
# 40      62     99.0   92.0     42.0            61.0

# %%
X_train.tail()
# Out:
#      Tamil  English  Maths  Science  Social Science
# 140     32     34.0   81.0     80.0            94.0
# 45      90     95.0   74.0     57.0            76.0
# 173     72     69.0   32.0     64.0            77.0
# 165     71     58.0   61.0     65.0            79.0
# 37      57     83.0   63.0     57.0            53.0

# %%
X_test.head()
# Out:
#      Tamil  English  Maths  Science  Social Science
# 143     59     97.0   59.0     85.0            45.0
# 81      96     87.0   66.0     57.0            47.0
# 26     100     50.0   81.0     53.0            53.0
# 150     70     77.0   53.0     94.0            64.0
# 124     79     42.0   75.0     50.0            47.0

# %%
X_test.tail()
# Out:
#      Tamil  English  Maths  Science  Social Science
# 25      88     78.0   79.0     46.0            46.0
# 1       58     83.0   86.0     89.0            96.0
# 149     49     64.0   97.0     58.0            79.0
# 193     89     46.0   51.0     55.0            75.0
# 121     99    100.0  100.0     89.0            97.0

# %%
Y_train.head()
# Out:
# 125    365.0
# 60     339.0
# 90     381.0
# 152    380.0
# 40     356.0
# Name: Total Mark, dtype: float64

# %%
Y_train.tail()
# Out:
# 140    321.0
# 45     392.0
# 173    314.0
# 165    334.0
# 37     313.0
# Name: Total Mark, dtype: float64

# %%
Y_test.head()
# Out:
# 143    345.0
# 81     353.0
# 26     337.0
# 150    358.0
# 124    293.0
# Name: Total Mark, dtype: float64

# %%
Y_test.tail()
# Out:
# 25     337.0
# 1      412.0
# 149    347.0
# 193    316.0
# 121    485.0
# Name: Total Mark, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([346.07593321, 354.05720817, 337.93683469, 359.29437682,
#        293.78425958, 300.66849463, 372.05750245, 421.98076898,
#        407.5341687 , 325.68178071, 334.18416554, 423.37242838,
#        313.54903599, 302.7229146 , 437.00246901, 293.51496588,
#        326.01481222, 371.96958479, 423.03509778, 366.83765122,
#        318.13541102, 204.71454724, 211.37958429, 403.67822748,
#        302.90100688, 351.57623877, 283.76255864, 443.86109715,
#        174.72871328, 413.8518533 , 264.31372514, 367.77921146,
#        356.11341269, 263.119815  , 159.77718746, 337.79100472,
#        412.90514897, 347.45639267, 317.09522714, 486.13001314])

# %%
Y_test
# Out:
# 143    345.000000
# 81     353.000000
# 26     337.000000
# 150    358.000000
# 124    293.000000
# 24     300.000000
# 126    371.000000
# 142    331.371859
# 129    406.000000
# 171    324.000000
# 72     333.000000
# 97     422.000000
# 21     313.000000
# 67     302.000000
# 106    436.000000
# 184    293.000000
# 111    325.000000
# 63     371.000000
# 93     401.000000
# 183    366.000000
# 86     317.000000
# 158    204.000000
# 133    211.000000
# 50     403.000000
# 99     302.000000
# 199    351.000000
# 189    283.000000
# 101    443.000000
# 100    174.000000
# 103    413.000000
# 139    264.000000
# 57     367.000000
# 36     355.000000
# 114    262.000000
# 54     159.000000
# 25     337.000000
# 1      412.000000
# 149    347.000000
# 193    316.000000
# 121    485.000000
# Name: Total Mark, dtype: float64

# %%
import joblib

joblib.dump(model, 'class5.pkl')
# Out:
# ['class5.pkl']

# %%
import joblib

# Load the model from the file
loaded_model = joblib.load('class5.pkl')

# Make predictions with the loaded model
Y_pred = loaded_model.predict([[82,96,89,56,50]])
print(Y_pred)
# Out:
# [373.76262162]
# C:\Users\Administrator\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
sum([82,96,89,56,50])
# Out:
# 373

# %%
Y_pred = loaded_model.predict([[50,50,50,50,50]])
print(Y_pred)
# Out:
# [250.74069417]
# C:\Users\Administrator\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
sum([50,50,50,50,50])
# Out:
# 250

# %%
# import pandas as pd
# import matplotlib.pylot as plt

# # df=pd.read_csv("Students Mark List.csv")
# # df.plot()
# # plt.show

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Students Mark List.csv")

df.plot()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1,2,3])
y = np.array([1, 2,3,4])

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10,11,12,34])

plt.plot(ypoints, marker = '>')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.barh(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.1, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()
